# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# Some common data problems
# <ol>
#     <li>Inconsitent column names</li>
#     <li>Missing data</li>
#     <li>Outliers</li>
#     <li>Duplicate rows etc.</li>
# </ol>

# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('dob_job_application_filings_subset.csv')
df.head()
df
# Out:
#            Job #  Doc #        Borough       House #  \
# 0      121577873      2      MANHATTAN  386
# 1      520129502      1  STATEN ISLAND  107
# 2      121601560      1      MANHATTAN  63
# 3      121601203      1      MANHATTAN  48
# 4      121601338      1      MANHATTAN  45
# ...          ...    ...            ...           ...
# 12841  520143988      1  STATEN ISLAND  8
# 12842  121613833      1      MANHATTAN  724
# 12843  121681260      1      MANHATTAN  350
# 12844  320771704      1       BROOKLYN  499
# 12845  520143951      1  STATEN ISLAND  1755
#
#                             Street Name  Block  Lot    Bin # Job Type  \
# 0      PARK AVENUE SOUTH                   857   38  1016890       A2
# 1      KNOX PLACE                          342    1  5161350       A3
# 2      WEST 131 STREET                    1729    9  1053831       A2
# 3      WEST 25TH STREET                    826   69  1015610       A2
# ...

# %% [markdown]
# ### Selecting only a few columns

# %%
selected_columns = df[['Job #', 'Doc #', 'Borough', 'Initial Cost', 'Total Est. Fee', 'Existing Zoning Sqft', \
                    'Proposed Zoning Sqft', 'Enlargement SQ Footage', 'Street Frontage', 'ExistingNo. of Stories', \
                    'Proposed No. of Stories', 'Existing Height', 'Proposed Height']]

df_subset=selected_columns
df_subset.head()
# Out:
#        Job #  Doc #        Borough Initial Cost Total Est. Fee  \
# 0  121577873      2      MANHATTAN    $75000.00        $986.00
# 1  520129502      1  STATEN ISLAND        $0.00       $1144.00
# 2  121601560      1      MANHATTAN    $30000.00        $522.50
# 3  121601203      1      MANHATTAN     $1500.00        $225.00
# 4  121601338      1      MANHATTAN    $19500.00        $389.50
#
#    Existing Zoning Sqft  Proposed Zoning Sqft  Enlargement SQ Footage  \
# 0                     0                     0                       0
# 1                     0                     0                       0
# 2                     0                     0                       0
# 3                     0                     0                       0
# 4                     0                     0                       0
#
#    Street Frontage  ExistingNo. of Stories  Proposed No. of Stories  \
# 0                0                       0                        0
# ...

# %% [markdown]
# #### Q. What data inconsistencies can you see above?

# %%
#YOUR CODE HERE

# %% [markdown]
# #### Q2. What is the data type of the variables `Initial Cost` and `Total Est. Fee`? Do we need to change them?

# %%
df_subset['Initial Cost'] = use a lambda function here
# Out:
#   File "<ipython-input-12-bb719ee2f725>", line 1
#     df_subset['Initial Cost'] = use a lambda function here
#                                     ^
# SyntaxError: invalid syntax

# %%
df_subset.info()

# %%
df_subset['Initial Cost'] =df.apply(pd.to_numeric, errors='coerce')
df_subset.head()
# Out:
#        Job #  Doc #        Borough  Initial Cost Total Est. Fee  \
# 0  121577873      2      MANHATTAN   121577873.0        $986.00
# 1  520129502      1  STATEN ISLAND   520129502.0       $1144.00
# 2  121601560      1      MANHATTAN   121601560.0        $522.50
# 3  121601203      1      MANHATTAN   121601203.0        $225.00
# 4  121601338      1      MANHATTAN   121601338.0        $389.50
#
#    Existing Zoning Sqft  Proposed Zoning Sqft  Enlargement SQ Footage  \
# 0                     0                     0                       0
# 1                     0                     0                       0
# 2                     0                     0                       0
# 3                     0                     0                       0
# 4                     0                     0                       0
#
#    Street Frontage  ExistingNo. of Stories  Proposed No. of Stories  \
# 0                0                       0                        0
# ...

# %%
df_subset.info()

# %% [markdown]
# #### Do the same operation on the column `Total Est. Fee`

# %% [markdown]
# ### Frequency counts for categorical data

# %%
df.info()

# %%
df['Borough'].value_counts()
# Out:
# MANHATTAN        6310
# BROOKLYN         2866
# QUEENS           2121
# BRONX             974
# STATEN ISLAND     575
# Name: Borough, dtype: int64

# %%
df['Borough'].value_counts(dropna=False)
# Out:
# MANHATTAN        6310
# BROOKLYN         2866
# QUEENS           2121
# BRONX             974
# STATEN ISLAND     575
# Name: Borough, dtype: int64

# %%
df['Site Fill'].value_counts()
# Out:
# NOT APPLICABLE                              7806
# ON-SITE                                      519
# OFF-SITE                                     186
# USE UNDER 300 CU.YD                          130
# Name: Site Fill, dtype: int64

# %%
df['Site Fill'].value_counts(dropna=False)
# Out:
# NOT APPLICABLE                              7806
# NaN                                         4205
# ON-SITE                                      519
# OFF-SITE                                     186
# USE UNDER 300 CU.YD                          130
# Name: Site Fill, dtype: int64

# %% [markdown]
# ### Summary statistics for numerical data

# %%
df_subset.describe()
# Out:
#               Job #         Doc #  Existing Zoning Sqft  Proposed Zoning Sqft  \
# count  1.284600e+04  12846.000000          1.284600e+04          1.284600e+04
# mean   2.426788e+08      1.162930          1.439973e+03          2.007286e+03
# std    1.312507e+08      0.514937          3.860757e+04          4.081570e+04
# min    1.036438e+08      1.000000          0.000000e+00          0.000000e+00
# 25%    1.216206e+08      1.000000          0.000000e+00          0.000000e+00
# 50%    2.202645e+08      1.000000          0.000000e+00          0.000000e+00
# 75%    3.208652e+08      1.000000          0.000000e+00          0.000000e+00
# max    5.400246e+08      9.000000          2.873107e+06          2.873107e+06
#
#        Enlargement SQ Footage  Street Frontage  ExistingNo. of Stories  \
# count            12846.000000     12846.000000            12846.000000
# mean                46.101432         3.069360                8.062354
# ...

# %% [markdown]
# ### EDA

# %%
df_subset.head()
# Out:
#        Job #  Doc #        Borough Initial Cost Total Est. Fee  \
# 0  121577873      2      MANHATTAN    $75000.00        $986.00
# 1  520129502      1  STATEN ISLAND        $0.00       $1144.00
# 2  121601560      1      MANHATTAN    $30000.00        $522.50
# 3  121601203      1      MANHATTAN     $1500.00        $225.00
# 4  121601338      1      MANHATTAN    $19500.00        $389.50
#
#    Existing Zoning Sqft  Proposed Zoning Sqft  Enlargement SQ Footage  \
# 0                     0                     0                       0
# 1                     0                     0                       0
# 2                     0                     0                       0
# 3                     0                     0                       0
# 4                     0                     0                       0
#
#    Street Frontage  ExistingNo. of Stories  Proposed No. of Stories  \
# 0                0                       0                        0
# ...

# %% [markdown]
# #### Q3. Create a boxplot to visualize how `initial_cost` varies by `Borough`

# %%
import matplotlib.pyplot as plt

# %%
df_subset.boxplot(column='Initial Cost', by='Borough') #YOUR CODE HERE
# Out:
# <AxesSubplot:title={'center':'Initial Cost'}, xlabel='Borough'>

# %% [markdown]
# #### Q4. Can you see the outliers?

# %%
df_subset.head()
# Out:
#        Job #  Doc #        Borough  Initial Cost Total Est. Fee  \
# 0  121577873      2      MANHATTAN   121577873.0        $986.00
# 1  520129502      1  STATEN ISLAND   520129502.0       $1144.00
# 2  121601560      1      MANHATTAN   121601560.0        $522.50
# 3  121601203      1      MANHATTAN   121601203.0        $225.00
# 4  121601338      1      MANHATTAN   121601338.0        $389.50
#
#    Existing Zoning Sqft  Proposed Zoning Sqft  Enlargement SQ Footage  \
# 0                     0                     0                       0
# 1                     0                     0                       0
# 2                     0                     0                       0
# 3                     0                     0                       0
# 4                     0                     0                       0
#
#    Street Frontage  ExistingNo. of Stories  Proposed No. of Stories  \
# 0                0                       0                        0
# ...

# %%
df_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12846 entries, 0 to 12845
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Job #                    12846 non-null  int64
#  1   Doc #                    12846 non-null  int64
#  2   Borough                  12846 non-null  object
#  3   Initial Cost             12846 non-null  float64
#  4   Total Est. Fee           12846 non-null  object
#  5   Existing Zoning Sqft     12846 non-null  int64
#  6   Proposed Zoning Sqft     12846 non-null  int64
#  7   Enlargement SQ Footage   12846 non-null  int64
#  8   Street Frontage          12846 non-null  int64
#  9   ExistingNo. of Stories   12846 non-null  int64
#  10  Proposed No. of Stories  12846 non-null  int64
#  11  Existing Height          12846 non-null  int64
#  12  Proposed Height          12846 non-null  int64
# dtypes: float64(1), int64(10), object(2)
# memory usage: 1.3+ MB

# %%
df_subset['Initial Cost'].plot(kind='hist')
plt.show()

# %%
df_subset['Initial Cost'].plot(kind='hist', bins=int(np.sqrt(12846)))
plt.show()

# %%
df_subset['Initial Cost'].value_counts()
# Out:
# 402889843.0    6
# 320742461.0    5
# 320761886.0    5
# 402890403.0    5
# 121603283.0    5
#               ..
# 340061042.0    1
# 420855729.0    1
# 121639904.0    1
# 121612326.0    1
# 121634874.0    1
# Name: Initial Cost, Length: 11658, dtype: int64

# %%
df_subset['Total Est. Fee']= df.apply(pd.to_numeric, errors='coerce') # converting numeric data

df_subset['Total Est. Fee'].plot(kind='hist', bins=int(np.sqrt(12846)))  #could not 
plt.show()

# %%
df_subset.plot(kind='scatter', x='Initial Cost', y='Total Est. Fee')
plt.show()

# %% [markdown]
# ### Converting data types

# %% [markdown]
# #### Working with categorical data

# %%
tips = pd.read_csv('tips.csv')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
# Convert the sex column to type 'category'
tips['sex'] = tips.sex.astype('category')


# Convert the smoker column to type 'category'
# tips['smoker'] = tips.smoker.astype('category') #YOUR CODE HERE

# Print the info of tips
print(tips.info())
# type(tips['sex'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: category(2), float64(2), int64(1), object(2)
# memory usage: 10.3+ KB
# None

# %% [markdown]
# #### Q5. What is your observation on the total file size?

# %% [markdown]
# #### Working with numeric data

# %%
tips.head()
# Out:
#    total_bill   tip     sex  smoker  day    time  size
# 0       16.99  1.01  Female  Female  Sun  Dinner     2
# 1       10.34  1.66    Male    Male  Sun  Dinner     3
# 2       21.01  3.50    Male    Male  Sun  Dinner     3
# 3       23.68  3.31    Male    Male  Sun  Dinner     2
# 4       24.59  3.61  Female  Female  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: category(2), float64(2), int64(1), object(2)
# memory usage: 10.3+ KB

# %%
tips['total_bill'][0] = '-'
tips.head()
# Out:
#   total_bill   tip     sex  smoker  day    time  size
# 0          -  1.01  Female  Female  Sun  Dinner     2
# 1      10.34  1.66    Male    Male  Sun  Dinner     3
# 2      21.01  3.50    Male    Male  Sun  Dinner     3
# 3      23.68  3.31    Male    Male  Sun  Dinner     2
# 4      24.59  3.61  Female  Female  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    object
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: category(2), float64(1), int64(1), object(3)
# memory usage: 10.3+ KB

# %%
# Convert 'total_bill' to a numeric dtype
tips['total_bill'] =  pd.to_numeric(tips['total_bill'], errors='coerce') #YOUR CODE HERE
tips.head()
# Out:
#    total_bill   tip     sex  smoker  day    time  size
# 0         NaN  1.01  Female  Female  Sun  Dinner     2
# 1       10.34  1.66    Male    Male  Sun  Dinner     3
# 2       21.01  3.50    Male    Male  Sun  Dinner     3
# 3       23.68  3.31    Male    Male  Sun  Dinner     2
# 4       24.59  3.61  Female  Female  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  243 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: category(2), float64(2), int64(1), object(2)
# memory usage: 10.3+ KB

# %%
tips['total_bill'].isna()
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Name: total_bill, Length: 244, dtype: bool

# %%
tips['total_bill'].isna().sum()
# Out:
# 1

# %%
tips.isna().sum()
# Out:
# total_bill    1
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64
